# %% [markdown]
# <a href="https://colab.research.google.com/github/FGalvao77/Natural-Language-Processing-NLP-with-Python-using-NLTK-Poemas-de-Fernando-Pesssoa/blob/main/Natural_Language_Processing_(NLP)_with_Python_using_NLTK_Poemas_de_Fernando_Pesssoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Natural Language Processing (NLP) with Python using `NLTK` - Poemas de Fernando Pesssoa**
#
# ---

# %% [markdown]
# Analisando as palavras mais frequentes nos **Os 10 melhores poemas de `Fernando Pessoa`**
#
# - Fonte: [Revista Bula](https://www.revistabula.com/522-os-10-melhores-poemas-de-fernando-pessoa-2/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Link do arquivo:
# - https://bit.ly/3qh6hLI

# %%
# importando os dados para o google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cbc581dd-813d-4b45-811d-093efa12996f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbc581dd-813d-4b45-811d-093efa12996f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Os 10 melhores poemas de Fernando Pessoa.txt to Os 10 melhores poemas de Fernando Pessoa.txt

# %%
# importando a biblioteca
import nltk

# %%
# instalando os pacotes necessários da biblioteca
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
# ...

# %%
# realizando a leitura do arquivo de texto
with open('/content/Os 10 melhores poemas de Fernando Pessoa.txt', 'r') as my_file:
    data = my_file.read().replace('\n', '')

# %%
# visualizando o arquivo de texto
data
# Out:
# 'Os 10 melhores poemas de Fernando Pessoa.Tabacaria.Não sou nada.Nunca serei nada.Não posso querer ser nada.À parte isso, tenho em mim todos os sonhos do mundo.Janelas do meu quarto,Do meu quarto de um dos milhões do mundo que ninguém sabe quem é(E se soubessem quem é, o que saberiam?),Dais para o mistério de uma rua cruzada constantemente por gente,Para uma rua inacessível a todos os pensamentos,Real, impossivelmente real, certa, desconhecidamente certa,Com o mistério das coisas por baixo das pedras e dos seres,Com a morte a pôr humidade nas paredes e cabelos brancos nos homens,Com o Destino a conduzir a carroça de tudo pela estrada de nada.Estou hoje vencido, como se soubesse a verdade.Estou hoje lúcido, como se estivesse para morrer,E não tivesse mais irmandade com as coisasSenão uma despedida, tornando-se esta casa e este lado da ruaA fileira de carruagens de um comboio, e uma partida apitadaDe dentro da minha cabeça,E uma sacudidela dos meus nervos e um ranger de ossos na ida.Es
# ...

# %%
# contabilizando a quantidade de palavras no texto
len(data)
# Out:
# 16408

# %%
# visualizando o tipo da variável
type(data)
# Out:
# str

# %%
# importando a função para expressões regulares
from nltk.tokenize import RegexpTokenizer

# %%
# instanciando o tokenizador
tokenizer = RegexpTokenizer(r'\w+')

# %%
# instanciando o arquivo de texto na variável "corpus"
corpus = open('/content/Os 10 melhores poemas de Fernando Pessoa.txt').read()

# %%
# realizando a tokenização da variável "corpus" com a função"regex"
# e salvando o resultado na variável "tokens"
tokens = tokenizer.tokenize(corpus)

# %%
# visualizando os 20 primeiros tokens
tokens[:20]
# Out:
# ['Os',
#  '10',
#  'melhores',
#  'poemas',
#  'de',
#  'Fernando',
#  'Pessoa',
#  'Tabacaria',
#  'Não',
#  'sou',
#  'nada',
#  'Nunca',
#  'serei',
#  'nada',
#  'Não',
#  'posso',
#  'querer',
#  'ser',
#  'nada',
#  'À']

# %%
# otimizando o código de tratamento do texto

# importando a função "regex" para tokenização
from nltk.tokenize import RegexpTokenizer

# instanciando o caminho do arquivo de texto
corpus = open('/content/Os 10 melhores poemas de Fernando Pessoa.txt').read()

# instanciando a função "regex" na variável "tokenizer"
tokenizer = RegexpTokenizer(r'[a-zA-Z]\w*') # ignorando todos os símbolos e números

# aplicando a tokenização e salvando o resultado na variável "tokens"
tokens = tokenizer.tokenize(corpus)

# instanciando a lista de stopwords na variável "stopwords"
stopwords = nltk.corpus.stopwords.words('portuguese')

# criando uma list comprehesion para tratar o arquivo de texto
texto_tratado = [token.lower() for token in tokens if token.lower() not in stopwords]

# %%
# visualizando o texto após o tratamento
texto_tratado[:10]
# Out:
# ['melhores',
#  'poemas',
#  'fernando',
#  'pessoa',
#  'tabacaria',
#  'nada',
#  'nunca',
#  'nada',
#  'posso',
#  'querer']

# %%
# imprimindo as frequências das palavras
freq = nltk.FreqDist(texto_tratado)
freq.most_common(30)  # visualizando as 30 palavras mais frequentes
# Out:
# [('mim', 18),
#  ('ser', 15),
#  ('tudo', 14),
#  ('coisa', 13),
#  ('nunca', 12),
#  ('nada', 11),
#  ('sempre', 11),
#  ('amor', 11),
#  ('mundo', 10),
#  ('hoje', 10),
#  ('tempo', 10),
#  ('todos', 9),
#  ('vejo', 9),
#  ('alma', 9),
#  ('sido', 9),
#  ('ridículas', 9),
#  ('tabacaria', 8),
#  ('sabe', 8),
#  ('casa', 8),
#  ('sei', 8),
#  ('tantas', 8),
#  ('porque', 8),
#  ('cartas', 8),
#  ('rua', 7),
#  ('gente', 7),
#  ('janela', 7),
#  ('outra', 7),
#  ('versos', 7),
#  ('vezes', 7),
#  ('ter', 7)]

# %%
# importando a biblioteca para visualização gráfica
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# visualizando as 30 palavras mais frequentes - unigramas
plt.figure(figsize=[12, 7])
nlp_words = nltk.FreqDist(texto_tratado)
plot1 = nlp_words.plot(30, color = 'salmon', 
                       title = 'Frequência de palavras - unigramas')

# %%
# importando as funções "bigrams" e "trigrams"
from nltk import bigrams, trigrams

# %%
# instanciando os bigramas
tokens = texto_tratado
tokens_bigrams = list(bigrams(tokens))

tokens_bigrams[:10]
# Out:
# [('melhores', 'poemas'),
#  ('poemas', 'fernando'),
#  ('fernando', 'pessoa'),
#  ('pessoa', 'tabacaria'),
#  ('tabacaria', 'nada'),
#  ('nada', 'nunca'),
#  ('nunca', 'nada'),
#  ('nada', 'posso'),
#  ('posso', 'querer'),
#  ('querer', 'ser')]

# %%
# visualizando as 30 palavras mais frequentes - bigramas
plt.figure(figsize=[12, 7])
bigrm = list(nltk.bigrams(texto_tratado))
words2 = nltk.FreqDist(bigrm)
words2.plot(30, color = 'salmon', 
           title = 'Frequência de palavras - bigramas')

# %%
# instanciando os trigramas
tokens = texto_tratado
tokens_trigrams = list(trigrams(tokens))

tokens_trigrams[:10]
# Out:
# [('melhores', 'poemas', 'fernando'),
#  ('poemas', 'fernando', 'pessoa'),
#  ('fernando', 'pessoa', 'tabacaria'),
#  ('pessoa', 'tabacaria', 'nada'),
#  ('tabacaria', 'nada', 'nunca'),
#  ('nada', 'nunca', 'nada'),
#  ('nunca', 'nada', 'posso'),
#  ('nada', 'posso', 'querer'),
#  ('posso', 'querer', 'ser'),
#  ('querer', 'ser', 'nada')]

# %%
# visualizando as 30 palavras mais frequentes - trigramas
plt.figure(figsize=[12, 7])
trigrm = list(nltk.trigrams(texto_tratado))
words3 = nltk.FreqDist(trigrm)
words3.plot(30, color = 'salmon', 
           title = 'Frequência de palavras - trigramas')

# %%
# importando as demias bibliotecas para auxiliar nas visualizações gráficas
# import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# exemplos de comentários da lista "all_words"
display(texto_tratado[27:45])
display(texto_tratado[99])
display(texto_tratado[243])
display(texto_tratado[802])
# Out:
# ['mistério',
#  'rua',
#  'cruzada',
#  'constantemente',
#  'gente',
#  'rua',
#  'inacessível',
#  'todos',
#  'pensamentos',
#  'real',
#  'impossivelmente',
#  'real',
#  'certa',
#  'desconhecidamente',
#  'certa',
#  'mistério',
#  'coisas',
#  'baixo']
# 'rua'
# 'more'
# 'moços'

# %%
# realizando a concatenação das palavras
all_summary = ' '.join(s for s in texto_tratado)

# %%
# instanciando a lista de stopwords na variável "stopwords"
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
# gerando uma wordcloud - nuvem de palavras
wordcloud = WordCloud(stopwords=stopwords,
                      background_color='white',
                      width=1600, height=800, 
                      max_words=300).generate(all_summary)
 
# mostrando a imagem final
fig, ax = plt.subplots(figsize=(18, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud);

# salvando a imagem
wordcloud.to_file('poemasfernandopessoa_summary_wordcloud.png');

# %%
# carregando a imagem para o google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-abd35b67-87d3-4b78-8b26-87db01b5c4e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abd35b67-87d3-4b78-8b26-87db01b5c4e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fernandopdes.jpg to fernandopdes.jpg

# %%
# importando a biblioteca
import numpy as np

# %%
# criando uma máscara com a imagem
fernandopessoa_mask = np.array(Image.open('/content/fernandopdes.jpg'))

# %%
# gerando uma wordcloud - nuvem de palavras com a imagem de "Fernando Pessoa"
wordcloud = WordCloud(stopwords=stopwords,
                      background_color='black',
                      width=1200, height=620, max_words=300,
                      mask=fernandopessoa_mask, max_font_size=200,
                      min_font_size=1).generate(all_summary)
 
# mostrando a imagem final
fig, ax = plt.subplots(figsize=(18, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud)

# salvando a imagem
wordcloud.to_file('poemasfernandopessoa2_summary_wordcloud.png');

# %%
# atualizando a lista de stopwords
stopwords = set(STOPWORDS)
stopwords.update(['porque', 'rua', 'cai', 'tabacaria'])

# %%
# gerando uma nova wordcloud - nuvem de palavras com a imagem de "Fernando Pessoa"
wordcloud = WordCloud(stopwords=stopwords,
                      background_color='black',
                      width=1200, height=620, max_words=300,
                      mask=fernandopessoa_mask, max_font_size=200,
                      min_font_size=1).generate(all_summary)
 
# mostrando a imagem final
fig, ax = plt.subplots(figsize=(18, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud)

# salvando a imagem
wordcloud.to_file('poemasfernandopessoa3_summary_wordcloud.png');
